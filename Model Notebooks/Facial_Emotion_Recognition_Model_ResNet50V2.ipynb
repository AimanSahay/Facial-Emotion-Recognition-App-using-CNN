# %% [markdown]
# ## **Introduction**
#
# DeepFER: Facial Emotion Recognition Using Deep Learning is a project aimed at developing a robust and efficient system for automatically identifying human emotions from facial expressions. By leveraging advanced deep learning techniques, particularly Convolutional Neural Networks (CNNs) and Transfer Learning, DeepFER is designed to classify emotions such as happiness, sadness, anger, surprise, fear, disgust, and neutrality from facial images.
#
# Facial emotion recognition plays a crucial role in numerous applications, including human-computer interaction, customer service, and mental health monitoring. Traditional approaches relied on handcrafted features and rule-based systems, which often struggled to generalize across diverse faces and real-world conditions. DeepFER addresses these challenges by using deep neural networks to automatically learn hierarchical features from raw image data, achieving high accuracy and real-time performance.
#
# The ultimate goal of DeepFER is to create a versatile and practical tool that allows machines to understand and respond to human emotions, bridging the gap between artificial intelligence and empathetic human-machine interactions.
#
# ---
#
# ## **Dataset Overview**
#
# DeepFER utilizes the **FER-2013 dataset**, a widely used benchmark for facial emotion recognition. Key characteristics of the dataset are:
#
# * **Image Format:** 48x48 pixel grayscale images
# * **Data Alignment:** Faces are automatically registered to be centered and occupy a similar area within the image
# * **Dataset Size:**
#
#   * Total: 24,400 images
#   * Training set: 22,968 images
#   * Public test set: 1,432 images
# * **Emotion Classes:**
#
#   1. Angry
#   2. Disgust
#   3. Fear
#   4. Happy
#   5. Sad
#   6. Surprise
#   7. Neutral
# * **Data Characteristics:**
#
#   * Grayscale images to simplify computational requirements
#   * Poses are consistent to focus on facial expressions
#   * Captures both posed and spontaneous expressions for better generalization
#
# The FER-2013 dataset provides a solid foundation for training and evaluating the DeepFER model, allowing for accurate and real-time classification of seven distinct human emotions.

# %% [markdown]
# ## **Installing Required Libraries**

# %%
# Upgrade pip (optional but recommended)
# !pip install --upgrade pip

# Install required libraries
# !pip install tensorflow keras opencv-python-headless numpy pandas scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (3.13.2)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.81.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras) (0.19.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)

# %% [markdown]
# ## **Verify Installations**

# %%
import tensorflow as tf
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

print("TensorFlow version:", tf.__version__)
print("OpenCV version:", cv2.__version__)
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Seaborn version:", sns.__version__)
# Out:
# TensorFlow version: 2.20.0
# OpenCV version: 4.13.0
# NumPy version: 2.0.2
# Pandas version: 2.2.2
# Seaborn version: 0.13.2

# %%
import numpy as np             # Numerical operations
import pandas as pd            # Data manipulation / CSV I/O
import os                      # File system operations
import matplotlib.pyplot as plt  # Visualization
import seaborn as sns          # Enhanced visualization
import tensorflow as tf        # Deep learning framework
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization,GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax
import cv2                     # Image processing
from tensorflow.keras.applications import VGG16, InceptionResNetV2  # For transfer learning
from keras import regularizers                                     # Optional: add weight regularization
from keras.preprocessing import image                               # Alternative to tf.keras.preprocessing
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## **Data Ingestion**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets.zip" -d "/content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/"
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9040.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9101.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/911.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9179.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9205.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9232.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9251.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9261.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9281.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9302.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9333.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9369.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9370.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9474.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/949.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9602.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9606.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9842.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/fear/9898.jpg
#    creating: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10019.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10023.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10074.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10096.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10106.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10126.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10138.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10141.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1020.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10218.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10237.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10248.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10257.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1027.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10273.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10276.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10312.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10317.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10344.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10362.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10367.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10370.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10432.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10456.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10467.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10468.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10480.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10528.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10540.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10552.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1056.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10571.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1058.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10622.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10638.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10640.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10644.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10647.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10683.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10703.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1074.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10770.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10773.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10792.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1081.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10811.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10841.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10879.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10903.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10935.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10956.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/10992.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11019.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1111.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11150.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11208.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1121.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11236.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1130.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11345.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11349.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11392.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1141.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11500.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11508.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11516.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1152.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11530.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11549.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11552.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11558.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11573.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11575.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11588.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1159.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11594.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11604.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11614.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11637.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11646.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11658.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11717.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11733.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11763.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11766.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11772.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11785.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11793.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11808.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11814.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11819.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11835.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11842.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11850.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11885.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/11927.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12011.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1202.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12024.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12098.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12120.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12129.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12141.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12191.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12239.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12257.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12284.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12321.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12329.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12349.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12359.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12376.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12379.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12381.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12410.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1246.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12487.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12492.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12497.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12557.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12560.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12581.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12600.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12611.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12672.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12705.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12725.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12729.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12772.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12776.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12789.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12861.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12904.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12936.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12951.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12956.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/12957.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13037.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13073.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1309.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13105.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13108.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13127.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13139.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13151.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1316.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13204.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13228.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13283.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13317.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13322.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1334.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13348.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13353.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13363.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13366.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13385.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1341.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13427.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13428.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13449.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13456.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13476.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13502.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13526.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13528.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13570.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13584.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13590.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13615.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13618.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13655.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13703.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13706.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13715.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13757.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13761.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13792.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13802.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1381.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13833.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13848.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13874.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13877.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/139.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13911.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13912.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13925.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1395.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13955.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13968.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13969.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/13991.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14063.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14092.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/141.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14139.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14152.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14155.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14169.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14236.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14278.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14282.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14292.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14310.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14314.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14327.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14348.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14360.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14371.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14378.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14419.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14427.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14448.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14473.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14475.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14516.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14517.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14518.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14546.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14586.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14593.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14611.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14700.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14730.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14757.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14759.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14792.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14877.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1491.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14965.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/14973.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15039.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15060.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15077.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15099.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1512.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15147.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15181.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15212.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15216.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15221.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15229.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15257.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15269.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15271.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15292.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15310.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15323.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15331.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15335.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1538.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15397.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15400.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15409.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15426.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15432.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15438.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15443.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15455.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15494.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15520.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15523.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15589.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15616.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15621.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15677.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15708.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15758.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15767.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15791.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15843.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15854.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15885.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15910.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15966.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15976.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/15983.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16037.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16042.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16064.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16076.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16081.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16106.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16108.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16120.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16141.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16192.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16198.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16238.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16275.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1628.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16308.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16370.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16375.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1640.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16407.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16423.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16444.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16460.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16511.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16550.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16562.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16583.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16588.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16596.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16604.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16611.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16619.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16633.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16649.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16667.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16699.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/167.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/1670.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16700.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16712.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16734.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16738.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16751.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16752.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16759.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16770.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16795.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/happy/16799.jpg
# ...
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5138.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5178.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/518.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5310.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5375.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5419.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5450.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5513.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5530.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5595.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5636.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5664.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5706.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5771.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5778.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5855.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5893.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5938.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5943.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/5997.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6046.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6050.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6167.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6184.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6216.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6219.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6247.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6309.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6360.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6410.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6415.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6425.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6427.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/647.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6518.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6598.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6647.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/670.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6711.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6716.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/675.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6797.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6877.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/692.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/6966.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7024.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7032.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7153.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7203.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7211.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/726.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7459.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7512.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7562.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7582.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/759.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7626.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7761.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7774.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/78.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/783.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7865.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7874.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/788.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7926.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/7957.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8016.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8021.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8042.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8063.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8115.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8137.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8143.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8173.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8240.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8309.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8329.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8404.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8421.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/843.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8439.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8478.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8489.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/867.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8736.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8837.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8928.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/8973.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9017.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9021.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9118.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9141.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9162.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9309.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9367.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9380.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9450.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9467.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/947.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9499.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9541.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9546.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9560.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9630.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9644.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9681.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9776.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9786.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9806.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9830.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9853.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/9878.jpg
#  extracting: /content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation/surprise/993.jpg

# %%
train_dir = "/content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/train"
test_dir = "/content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/validation"

# %% [markdown]
# ## **Displaying one image for each emotion in train set**

# %%
import os
class_names = os.listdir("/content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets/train")
print(class_names)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
import os
import glob
import cv2
import matplotlib.pyplot as plt

dataset_path = r"/content/drive/MyDrive/Module_5_Specialization_Computer_Vision/DeepFER_datasets/DeepFER_datasets"

# Get all emotion folders inside train
emotion_folders = glob.glob(os.path.join(dataset_path, "train", "*"))

for folder in emotion_folders:
    emotion = os.path.basename(folder)

    # Get first image from the folder
    image_files = glob.glob(os.path.join(folder, "*"))

    if len(image_files) > 0:
        img = cv2.imread(image_files[-2])

        # Convert BGR to RGB for correct display
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        plt.figure(figsize=(4, 4))
        plt.imshow(img)
        plt.title(f"Displaying {emotion} emotion")
        plt.axis("off")
        plt.show()

# %%
# specifing new image shape for resnet
img_shape = 224
batch_size = 64

# %% [markdown]
# ## **ImageDataGenerators for ResNet50V2**

# %%
train_preprocessor = ImageDataGenerator(
    rescale=1/255.,
    rotation_range=20,              # better for face angles
    zoom_range=0.25,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    brightness_range=[0.7, 1.3],    # important for FER
    horizontal_flip=True,
    fill_mode='nearest',
)

test_preprocessor = ImageDataGenerator(
    rescale=1/255.,
)

# %% [markdown]
# ## **Data Loaders**

# %%
train_data = train_preprocessor.flow_from_directory(
    train_dir,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode='rgb',
    shuffle=True,
    batch_size=batch_size,
)

test_data = test_preprocessor.flow_from_directory(
    test_dir,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode="rgb",
    shuffle=False,
    batch_size=batch_size,
)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# **Why this step is required?**
#
# 1. Face emotions change with lighting, head angle, zoom level, etc.
# 2. Data augmentation simulates real-world variations → prevents overfitting.
# 3. rescale=1/255 normalizes pixel values → faster + more stable training.
# 4. Using augmentations only on training and NOT on test data ensures fair evaluation.

# %% [markdown]
# ## **Build ResNet50V2 Base Model**

# %%
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

num_classes = train_data.num_classes

base_model = ResNet50V2(
    weights='imagenet',
    include_top=False,
    input_shape=(img_shape, img_shape, 3)
)

base_model.trainable = False  # Freeze entire base
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# - ResNet50V2 already learned powerful visual features from millions of images.
# - Freezing layers prevents destroying those learned features.
# - Saves training time and prevents overfitting.

# %%
# Freezing all layers except last 50
base_model.trainable = True   # allow some layers to be trainable

for layer in base_model.layers[:-50]:
    layer.trainable = False

# %% [markdown]
# ## **Adding Custom Final Output Layers in ResNet50V2 Model**

# %%
# Load the base ResNet50V2 model (without the top classifier)
base_model = ResNet50V2(
    weights='imagenet',
    include_top=False,
    input_shape=(img_shape, img_shape, 3)
)

# Freeze all layers initially
base_model.trainable = False
print("Base ResNet50V2 model loaded and frozen.")
# Out:
# Base ResNet50V2 model loaded and frozen.

# %% [markdown]
# The original ResNet50V2 was trained for ImageNet (1000 classes).
# The FER dataset has 7 emotion classes, so a new a new classifier head must be added.
#
# | Layer                  | Why it is needed                                           |
# | ---------------------- | ---------------------------------------------------------- |
# | `Flatten()`            | Converts feature maps into a 1D vector for Dense layers    |
# | `Dense(64, relu)`      | Learns task-specific emotional features                    |
# | `BatchNormalization()` | Stabilizes training & reduces sensitivity to learning rate |
# | `Dropout`              | Prevents overfitting                                       |
# | `Dense(7, softmax)`    | Outputs 7 emotion class probabilities                      |

# %%
# Get output from base model
x = base_model.output

# Global Average Pooling (reduces feature maps)
x = GlobalAveragePooling2D()(x)

# Regularization to prevent overfitting
x = Dropout(0.3)(x)
x = BatchNormalization()(x)

# Fully Connected Layer
x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.4)(x)

# Final Output Layer
outputs = Dense(num_classes, activation='softmax')(x)

# Final ResNet50V2 model
model = Model(inputs=base_model.input, outputs=outputs)

# %% [markdown]
# ## **Compile the model**

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ input_layer_1[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 114, 114,  │          0 │ conv1_conv[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 56, 56,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_preac… │ (None, 56, 56,    │        256 │ pool1_pool[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_preac… │ (None, 56, 56,    │          0 │ conv2_block1_pre… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 56, 56,    │      4,096 │ conv2_block1_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 56, 56,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 56, 56,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_pad  │ (None, 58, 58,    │          0 │ conv2_block1_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 56, 56,    │     36,864 │ conv2_block1_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 56, 56,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 56, 56,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 56, 56,    │     16,640 │ conv2_block1_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 56, 56,    │          0 │ conv2_block1_0_c… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_preac… │ (None, 56, 56,    │      1,024 │ conv2_block1_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_preac… │ (None, 56, 56,    │          0 │ conv2_block2_pre… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 56, 56,    │     16,384 │ conv2_block2_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 56, 56,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 56, 56,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_pad  │ (None, 58, 58,    │          0 │ conv2_block2_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 56, 56,    │     36,864 │ conv2_block2_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 56, 56,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 56, 56,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 56, 56,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_preac… │ (None, 56, 56,    │      1,024 │ conv2_block2_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_preac… │ (None, 56, 56,    │          0 │ conv2_block3_pre… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 56, 56,    │     16,384 │ conv2_block3_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 56, 56,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 56, 56,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_pad  │ (None, 58, 58,    │          0 │ conv2_block3_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 28, 28,    │     36,864 │ conv2_block3_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 28, 28,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 28, 28,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 28, 28,    │          0 │ conv2_block2_out… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 28, 28,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 28, 28,    │          0 │ max_pooling2d_3[… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_preac… │ (None, 28, 28,    │      1,024 │ conv2_block3_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_preac… │ (None, 28, 28,    │          0 │ conv3_block1_pre… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 28, 28,    │     32,768 │ conv3_block1_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 28, 28,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 28, 28,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_pad  │ (None, 30, 30,    │          0 │ conv3_block1_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 28, 28,    │    147,456 │ conv3_block1_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 28, 28,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 28, 28,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 28, 28,    │    131,584 │ conv3_block1_pre… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 28, 28,    │          0 │ conv3_block1_0_c… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_preac… │ (None, 28, 28,    │      2,048 │ conv3_block1_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_preac… │ (None, 28, 28,    │          0 │ conv3_block2_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 28, 28,    │     65,536 │ conv3_block2_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 28, 28,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 28, 28,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_pad  │ (None, 30, 30,    │          0 │ conv3_block2_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 28, 28,    │    147,456 │ conv3_block2_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 28, 28,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 28, 28,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 28, 28,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_preac… │ (None, 28, 28,    │      2,048 │ conv3_block2_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_preac… │ (None, 28, 28,    │          0 │ conv3_block3_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 28, 28,    │     65,536 │ conv3_block3_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 28, 28,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 28, 28,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_pad  │ (None, 30, 30,    │          0 │ conv3_block3_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 28, 28,    │    147,456 │ conv3_block3_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 28, 28,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 28, 28,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 28, 28,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_preac… │ (None, 28, 28,    │      2,048 │ conv3_block3_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_preac… │ (None, 28, 28,    │          0 │ conv3_block4_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 28, 28,    │     65,536 │ conv3_block4_pre… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 28, 28,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 28, 28,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_pad  │ (None, 30, 30,    │          0 │ conv3_block4_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 14, 14,    │    147,456 │ conv3_block4_2_p… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 14, 14,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 14, 14,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 14, 14,    │          0 │ conv3_block3_out… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 14, 14,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 14, 14,    │          0 │ max_pooling2d_4[… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_preac… │ (None, 14, 14,    │      2,048 │ conv3_block4_out… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_preac… │ (None, 14, 14,    │          0 │ conv4_block1_pre… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 14, 14,    │    131,072 │ conv4_block1_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 14, 14,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_pad  │ (None, 16, 16,    │          0 │ conv4_block1_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 14, 14,    │    589,824 │ conv4_block1_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 14, 14,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 14, 14,    │    525,312 │ conv4_block1_pre… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 14, 14,    │          0 │ conv4_block1_0_c… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_preac… │ (None, 14, 14,    │      4,096 │ conv4_block1_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_preac… │ (None, 14, 14,    │          0 │ conv4_block2_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 14, 14,    │    262,144 │ conv4_block2_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 14, 14,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_pad  │ (None, 16, 16,    │          0 │ conv4_block2_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 14, 14,    │    589,824 │ conv4_block2_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 14, 14,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 14, 14,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_preac… │ (None, 14, 14,    │      4,096 │ conv4_block2_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_preac… │ (None, 14, 14,    │          0 │ conv4_block3_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 14, 14,    │    262,144 │ conv4_block3_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 14, 14,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_pad  │ (None, 16, 16,    │          0 │ conv4_block3_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 14, 14,    │    589,824 │ conv4_block3_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 14, 14,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 14, 14,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_preac… │ (None, 14, 14,    │      4,096 │ conv4_block3_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_preac… │ (None, 14, 14,    │          0 │ conv4_block4_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 14, 14,    │    262,144 │ conv4_block4_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 14, 14,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_pad  │ (None, 16, 16,    │          0 │ conv4_block4_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 14, 14,    │    589,824 │ conv4_block4_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 14, 14,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 14, 14,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_preac… │ (None, 14, 14,    │      4,096 │ conv4_block4_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_preac… │ (None, 14, 14,    │          0 │ conv4_block5_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 14, 14,    │    262,144 │ conv4_block5_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 14, 14,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_pad  │ (None, 16, 16,    │          0 │ conv4_block5_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 14, 14,    │    589,824 │ conv4_block5_2_p… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 14, 14,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 14, 14,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_preac… │ (None, 14, 14,    │      4,096 │ conv4_block5_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_preac… │ (None, 14, 14,    │          0 │ conv4_block6_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 14, 14,    │    262,144 │ conv4_block6_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 14, 14,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_pad  │ (None, 16, 16,    │          0 │ conv4_block6_1_r… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 7, 7, 256) │    589,824 │ conv4_block6_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 7, 7, 256) │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 7, 7, 256) │          0 │ conv4_block6_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 7, 7,      │          0 │ conv4_block5_out… │
# │ (MaxPooling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 7, 7,      │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 7, 7,      │          0 │ max_pooling2d_5[… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_preac… │ (None, 7, 7,      │      4,096 │ conv4_block6_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_preac… │ (None, 7, 7,      │          0 │ conv5_block1_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 7, 7, 512) │    524,288 │ conv5_block1_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_pad  │ (None, 9, 9, 512) │          0 │ conv5_block1_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 7, 7, 512) │  2,359,296 │ conv5_block1_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 7, 7,      │  2,099,200 │ conv5_block1_pre… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 7, 7,      │          0 │ conv5_block1_0_c… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_preac… │ (None, 7, 7,      │      8,192 │ conv5_block1_out… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_preac… │ (None, 7, 7,      │          0 │ conv5_block2_pre… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 7, 7, 512) │  1,048,576 │ conv5_block2_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_pad  │ (None, 9, 9, 512) │          0 │ conv5_block2_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 7, 7, 512) │  2,359,296 │ conv5_block2_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 7, 7,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_preac… │ (None, 7, 7,      │      8,192 │ conv5_block2_out… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_preac… │ (None, 7, 7,      │          0 │ conv5_block3_pre… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 7, 7, 512) │  1,048,576 │ conv5_block3_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_pad  │ (None, 9, 9, 512) │          0 │ conv5_block3_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 7, 7, 512) │  2,359,296 │ conv5_block3_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 7, 7,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ post_bn             │ (None, 7, 7,      │      8,192 │ conv5_block3_out… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ post_relu           │ (None, 7, 7,      │          0 │ post_bn[0][0]     │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ post_relu[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 2048)      │      8,192 │ dropout[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    524,544 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 7)         │      1,799 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,100,359 (91.94 MB)
#  Trainable params: 530,951 (2.03 MB)
#  Non-trainable params: 23,569,408 (89.91 MB)

# %%
#Import Callback Libaries
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import tensorflow as tf

# Model Checkpoint (Save Best Model)
checkpoint_path = "ResNet50V2_Best_Model.h5"

checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor="val_accuracy",
    save_best_only=True,
    mode='max',
    verbose=1
)

# Early stopping
early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=7,
    restore_best_weights=True,
    verbose=1
)

# Reduce Learning rate on Plateau
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=2,
    verbose=1,
    min_lr=1e-6
)
 # Combine All Callbacks
callbacks = [checkpoint_callback, early_stop, reduce_lr]

# Steps per Epoch Setup
steps_per_epoch = train_data.n // train_data.batch_size
validation_steps = test_data.n // test_data.batch_size

# %% [markdown]
# **Why they are required?**
#
# **1. EarlyStopping**
# - Stops training when validation accuracy stops improving.
# - Prevents overfitting and saves training time.
#
# **2. ReduceLROnPlateau**
# - If validation loss is not improving → reduce learning rate.
# - Helps model escape plateaus and find a better minimum.
#
# **3. ModelCheckpoint**
# - Saves the best model only, not the last one.
# - Prevents losing best weights in later bad epochs.

# %% [markdown]
# ## **Training the ResNet50V2 Model**

# %%
# --------------------------------------------
#  TRAINING THE RESNET50V2 MODEL
# --------------------------------------------
ResNet50V2_history = model.fit(
    train_data,
    validation_data=test_data,
    epochs=15,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/15
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3067 - loss: 2.1594
# Epoch 1: val_accuracy improved from None to 0.45028, saving model to ResNet50V2_Best_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to ResNet50V2_Best_Model.h5
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 656s 1s/step - accuracy: 0.3443 - loss: 1.8867 - val_accuracy: 0.4503 - val_loss: 1.4246 - learning_rate: 0.0010
# Epoch 2/15
#   1/450 ━━━━━━━━━━━━━━━━━━━━ 56s 126ms/step - accuracy: 0.4375 - loss: 1.3981
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy did not improve from 0.45028
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 36s 79ms/step - accuracy: 0.4375 - loss: 1.3981 - val_accuracy: 0.4482 - val_loss: 1.4277 - learning_rate: 0.0010
# Epoch 3/15
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3975 - loss: 1.5832
# Epoch 3: val_accuracy improved from 0.45028 to 0.48267, saving model to ResNet50V2_Best_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to ResNet50V2_Best_Model.h5
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 622s 1s/step - accuracy: 0.4042 - loss: 1.5566 - val_accuracy: 0.4827 - val_loss: 1.3592 - learning_rate: 0.0010
# Epoch 4/15
#   1/450 ━━━━━━━━━━━━━━━━━━━━ 56s 126ms/step - accuracy: 0.4062 - loss: 1.5378
# Epoch 4: val_accuracy did not improve from 0.48267
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 35s 79ms/step - accuracy: 0.4062 - loss: 1.5378 - val_accuracy: 0.4814 - val_loss: 1.3599 - learning_rate: 0.0010
# Epoch 5/15
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4208 - loss: 1.5072
# Epoch 5: val_accuracy improved from 0.48267 to 0.48849, saving model to ResNet50V2_Best_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5: finished saving model to ResNet50V2_Best_Model.h5
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 593s 1s/step - accuracy: 0.4243 - loss: 1.5037 - val_accuracy: 0.4885 - val_loss: 1.3441 - learning_rate: 0.0010
# Epoch 6/15
#   1/450 ━━━━━━━━━━━━━━━━━━━━ 1:00 135ms/step - accuracy: 0.4844 - loss: 1.4542
# Epoch 6: val_accuracy improved from 0.48849 to 0.49020, saving model to ResNet50V2_Best_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6: finished saving model to ResNet50V2_Best_Model.h5
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.4844 - loss: 1.4542 - val_accuracy: 0.4902 - val_loss: 1.3433 - learning_rate: 0.0010
# Epoch 7/15
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4290 - loss: 1.4904
# Epoch 7: val_accuracy improved from 0.49020 to 0.50128, saving model to ResNet50V2_Best_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: finished saving model to ResNet50V2_Best_Model.h5
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 559s 1s/step - accuracy: 0.4312 - loss: 1.4772 - val_accuracy: 0.5013 - val_loss: 1.3107 - learning_rate: 0.0010
# Epoch 8/15
#   1/450 ━━━━━━━━━━━━━━━━━━━━ 1:05 145ms/step - accuracy: 0.4688 - loss: 1.3572
# Epoch 8: val_accuracy did not improve from 0.50128
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 30s 67ms/step - accuracy: 0.4688 - loss: 1.3572 - val_accuracy: 0.4997 - val_loss: 1.3102 - learning_rate: 0.0010
# Epoch 9/15
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4332 - loss: 1.4680
# Epoch 9: val_accuracy improved from 0.50128 to 0.51009, saving model to ResNet50V2_Best_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 9: finished saving model to ResNet50V2_Best_Model.h5
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 574s 1s/step - accuracy: 0.4352 - loss: 1.4677 - val_accuracy: 0.5101 - val_loss: 1.3045 - learning_rate: 0.0010
# Epoch 10/15
#   1/450 ━━━━━━━━━━━━━━━━━━━━ 1:04 143ms/step - accuracy: 0.4375 - loss: 1.4139
# Epoch 10: val_accuracy improved from 0.51009 to 0.51051, saving model to ResNet50V2_Best_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 10: finished saving model to ResNet50V2_Best_Model.h5
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 31s 68ms/step - accuracy: 0.4375 - loss: 1.4139 - val_accuracy: 0.5105 - val_loss: 1.3042 - learning_rate: 0.0010
# Epoch 11/15
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4389 - loss: 1.4586
# Epoch 11: val_accuracy improved from 0.51051 to 0.51634, saving model to ResNet50V2_Best_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 11: finished saving model to ResNet50V2_Best_Model.h5
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 590s 1s/step - accuracy: 0.4383 - loss: 1.4592 - val_accuracy: 0.5163 - val_loss: 1.2960 - learning_rate: 0.0010
# Epoch 12/15
#   1/450 ━━━━━━━━━━━━━━━━━━━━ 1:06 148ms/step - accuracy: 0.4531 - loss: 1.5029
# Epoch 12: val_accuracy improved from 0.51634 to 0.51705, saving model to ResNet50V2_Best_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 12: finished saving model to ResNet50V2_Best_Model.h5
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.4531 - loss: 1.5029 - val_accuracy: 0.5170 - val_loss: 1.2957 - learning_rate: 0.0010
# Epoch 13/15
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4417 - loss: 1.4507
# Epoch 13: val_accuracy did not improve from 0.51705
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 533s 1s/step - accuracy: 0.4430 - loss: 1.4503 - val_accuracy: 0.5149 - val_loss: 1.2852 - learning_rate: 0.0010
# Epoch 14/15
#   1/450 ━━━━━━━━━━━━━━━━━━━━ 1:07 151ms/step - accuracy: 0.3750 - loss: 1.5754
# Epoch 14: val_accuracy did not improve from 0.51705
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 30s 66ms/step - accuracy: 0.3750 - loss: 1.5754 - val_accuracy: 0.5149 - val_loss: 1.2857 - learning_rate: 0.0010
# Epoch 15/15
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4407 - loss: 1.4381
# Epoch 15: val_accuracy improved from 0.51705 to 0.51875, saving model to ResNet50V2_Best_Model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 15: finished saving model to ResNet50V2_Best_Model.h5
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 543s 1s/step - accuracy: 0.4436 - loss: 1.4411 - val_accuracy: 0.5188 - val_loss: 1.2741 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 15.

# %% [markdown]
# * Model updates weights by learning patterns from training images.
# * Validation data monitors whether the model is generalizing.

# %% [markdown]
# ## **Evaluate ResNet50V2 Model**

# %%
from keras.models import load_model

ResNet50V2_Model = load_model("ResNet50V2_Best_Model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# --------------------------------------------
# 📌 MODEL EVALUATION ON TEST DATA
# --------------------------------------------
ResNet50V2_score = ResNet50V2_Model.evaluate(test_data)

print(f"Test Loss     : {ResNet50V2_score[0]:.5f}")
print(f"Test Accuracy : {ResNet50V2_score[1] * 100:.2f}%")
# Out:
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 42s 321ms/step - accuracy: 0.5192 - loss: 1.2735
# Test Loss     : 1.27350
# Test Accuracy : 51.92%

# %% [markdown]
# * Gives final performance on unseen test images.
# * Helps determine whether your model is ready for deployment.

# %%
# --------------------------------------------
# 📌 PLOT TRAINING & VALIDATION CURVES
# --------------------------------------------
import matplotlib.pyplot as plt

def plot_curves(history):

    acc      = history.history['accuracy']
    val_acc  = history.history['val_accuracy']
    loss     = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 4))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'r^-', label='Validation Accuracy')
    plt.title("Training vs Validation Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training Loss')
    plt.plot(epochs, val_loss, 'r^-', label='Validation Loss')
    plt.title("Training vs Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

    plt.show()

# %% [markdown]
# This Shows trends of training/validation accuracy and loss.
#
# Helps detect:
#
# * overfitting
# * underfitting
# * learning rate issues
# * whether more training is required

# %%
# Plot The Curve
plot_curves(ResNet50V2_history)

# %% [markdown]
# ## **Generate Predictions Correctly**

# %%
# --------------------------------------------
# 📌 PREDICTIONS
# --------------------------------------------
from tensorflow.keras.models import load_model

model = load_model('/content/ResNet50V2_Best_Model.h5')

pred_probs = model.predict(test_data)

ResNet50V2_Predictions = np.argmax(pred_probs, axis=1)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 40s 313ms/step

# %% [markdown]
# ## **Confusion Matrix**

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_data.labels, ResNet50V2_Predictions)

plt.figure(figsize=(12,8))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')

plt.xlabel("Predicted Labels", fontsize=14, fontweight='bold')
plt.ylabel("True Labels", fontsize=14, fontweight='bold')
plt.title("ResNet50V2 Confusion Matrix", fontsize=18, fontweight='bold')
plt.show()

# %% [markdown]
# A confusion matrix helps you understand class-wise performance:
#
# * Which emotions are misclassified?
# * Is the model confusing fear vs surprise?
# * Are minority classes underperforming?
# * It gives a much deeper understanding than accuracy alone.

# %% [markdown]
# ## **Class-wise Accuracy**

# %%
classes = list(test_data.class_indices.keys())

cm_df = pd.DataFrame(cm, index=classes, columns=classes)
display(cm_df)
# Out:
#           angry  disgust  fear  happy  neutral  sad  surprise
# angry       325        1    34    174      214  173        39
# disgust      21        3    10     28       24   21         4
# fear        125        2   193    143      225  202       128
# happy        83        1    35   1435      132   94        45
# neutral      79        1    44    162      747  147        36
# sad         113        1    77    162      302  462        22
# surprise     33        0    54     88      100   18       504

# %% [markdown]
# ## **Final Summary**
#
# | Step                           | Purpose                                        |
# | ------------------------------ | ---------------------------------------------- |
# | Data Augmentation              | Prevents overfitting & improves generalization |
# | Transfer Learning (ResNet50V2) | Uses powerful pre-learned features             |
# | Freeze Layers                  | Keeps useful ImageNet knowledge                |
# | Custom Head                    | Adapts model for 7-class emotion detection     |
# | Callbacks                      | Makes training stable and efficient            |
# | Model Training                 | Learns on your FER dataset                     |
# | Evaluation                     | Measures performance on unseen data            |
# | Plot Curves                    | Helps diagnose overfitting/underfitting        |
# | Confusion Matrix               | Checks class-wise model behavior               |

# %% [markdown]
# ## **Testing With Random Validation Data**

# %% [markdown]
# ### Emotion Class Names

# %%
Emotion_Classes = ['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %% [markdown]
# ### Creating Test Data Generator

# %%
# Shuffling Test Data to show diffrent classes
test_preprocessor = ImageDataGenerator(
        rescale = 1 / 255.,
    )

test_generator = test_preprocessor.flow_from_directory(
    test_dir,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode="rgb",
    shuffle=True,
    batch_size=batch_size,
)
# Out:
# Found 7066 images belonging to 7 classes.

# %%
# Display 10 random pictures from the dataset with their labels

Random_batch = np.random.randint(0, len(test_generator) - 1)

Random_Img_Index = np.random.randint(0, batch_size - 1 , 10)

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(25, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):

    Random_Img = test_generator[Random_batch][0][Random_Img_Index[i]]

    Random_Img_Label = np.argmax(test_generator[Random_batch][1][Random_Img_Index[i]])

    Model_Prediction = np.argmax(ResNet50V2_Model.predict( tf.expand_dims(Random_Img, axis=0) , verbose=0))

    ax.imshow(Random_Img)

    if Emotion_Classes[Random_Img_Label] == Emotion_Classes[Model_Prediction]:
          color = "green"
    else:
          color = "red"
    ax.set_title(f"True: {Emotion_Classes[Random_Img_Label]}\nPredicted: {Emotion_Classes[Model_Prediction]}", color=color)
plt.show()
plt.tight_layout()

# %%
model.save("/content/drive/MyDrive/Module_5_Specialization_Computer_Vision/ResNet50V2_Model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
